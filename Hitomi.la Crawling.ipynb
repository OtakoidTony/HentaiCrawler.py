# %% [markdown]
# # Hitomi.la Crawling

# %%
import requests
from bs4 import BeautifulSoup

number = '1262452'
input_url = 'https://hitomi.la/galleries/' + number + ".html"
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) '
                  'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}
res = requests.get(input_url, headers=headers)
soup = BeautifulSoup(res.content, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE HTML>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="1;url=https://hitomi.la/manga/minatsu-no-sei-|-미나츠의-탓-한국어-1262452.html" http-equiv="refresh"/>
# <script type="text/javascript">
#     window.location.href = "https://hitomi.la/manga/minatsu-no-sei-|-미나츠의-탓-한국어-1262452.html"
# </script>
# <title>Redirect</title>
# </head>
# <body>
# If you are not redirected automatically, follow the <a href="https://hitomi.la/manga/minatsu-no-sei-|-미나츠의-탓-한국어-1262452.html">link to the content</a>.
# </body>
# </html>

# %%
link = soup.find('a')
input_url = link.get('href')

res = requests.get(input_url, headers=headers)
soup = BeautifulSoup(res.content, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Minatsu no Sei | 미나츠의 탓 by henreader - Read Online - hentai manga | Hitomi.la</title>
# <meta content="Read Minatsu no Sei | 미나츠의 탓 by henreader online at Hitomi.la!" name="description"/>
# <meta content="width=device-width,initial-scale=1.0" name="viewport"/>
# <script>var galleryid = 1262452; var related = [1210666,892569,570442,1111923,1111566];</script>
# <script src="//ltn.hitomi.la/galleries/1262452.js"></script>
# <script src="//ltn.hitomi.la/jquery.min.js"></script>
# <script src="//ltn.hitomi.la/common.js"></script>
# <script src="//ltn.hitomi.la/js.cookie.js"></script>
# <script src="//ltn.hitomi.la/pagination.min.js"></script>
# <script src="//ltn.hitomi.la/moveimage.js"></script>
# <script src="//ltn.hitomi.la/limitlists.js"></script>
# <script src="//ltn.hitomi.la/moment-with-locales.js"></script>
# <script src="//ltn.hitomi.la/date.js"></script>
# <script src="//ltn.hitomi.la/FileSaver.min.js"></script>
# <script src="//ltn.hitomi.la/jszip.min.js"></script>
# <script src="//ltn.hitomi.la/download.js"></script>
# <script src="//ltn.hitomi.la/jquery-ui/jquery-ui.min.js"></script>
# <script src="//ltn.hitomi.la/tIongEnSEsCe26.js"></script>
# <script src="//ltn.hitomi.la/gallery.js"></script>
# <script src="//ltn.hitomi.la/yall.min.js"></script>
# <link href="//ltn.hitomi.la/gallery.css" rel="stylesheet"/>
# <link href="//ltn.hitomi.la/djtemplate.css" rel="stylesheet"/>
# <link href="//ltn.hitomi.la/pagination.css" rel="stylesheet"/>
# <link href="//ltn.hitomi.la/navbar.css" rel="stylesheet"/>
# <link href="//ltn.hitomi.la/search.css" rel="stylesheet"/>
# <link href="//ltn.hitomi.la/jquery-ui/jquery-ui.min.css" rel="stylesheet"/>
# <link href="//ltn.hitomi.la/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="//ltn.hitomi.la/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="//ltn.hitomi.la/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="//ltn.hitomi.la/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="//ltn.hitomi.la/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="//ltn.hitomi.la/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="//ltn.hitomi.la/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="//ltn.hitomi.la/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="//ltn.hitomi.la/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="//ltn.hitomi.la/favicon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="//ltn.hitomi.la/favicon-160x160.png" rel="icon" sizes="160x160" type="image/png"/>
# <link href="//ltn.hitomi.la/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="//ltn.hitomi.la/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="//ltn.hitomi.la/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <meta content="#2d89ef" name="msapplication-TileColor"/>
# <meta content="//ltn.hitomi.la/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="notranslate" name="google">
# </meta></head>
# <body>
# <div class="container">
# <div class="navbar">
# <div id="logo"><a href="/"><img src="//ltn.hitomi.la/logo.png"/></a></div>
# <nav>
# <ul>
# <li><a href="/alltags-a.html">tags</a></li>
# <li><a href="/allartists-a.html">artists</a></li>
# <li><a href="/allseries-a.html">series</a></li>
# <li><a href="/allcharacters-a.html">characters</a></li>
# </ul>
# </nav>
# <div class="drop-button">
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </div>
# <script src="//ltn.hitomi.la/searchlib.js"></script>
# <script src="//ltn.hitomi.la/search.js"></script>
# <div class="header-table">
# To enter a tag name with spaces, use the _ character.">
# <input id="query-input" placeholder="Search..." type="text"/>
# <ul id="search-suggestions"></ul>
# </div>
# <button id="search-button" type="button">Search</button>
# </div>
# </div>
# <div class="content">
# <div class="hitomi-TIoNchommo74"><script src="//ltn.hitomi.la/TIoNchommo74.js"></script></div>
# <div class="cover-column lillie">
# <div class="cover"><a href="/reader/1262452.html"><img src="//tn.hitomi.la/bigtn/1262452/1.jpg.jpg"/></a></div>
# <a href="/reader/1262452.html"><h1>Read Online</h1></a>
# <a href="#" id="dl-button" onclick="download_gallery('Minatsu no Sei | 미나츠의 탓');return false"><h1>Download</h1></a>
# <div id="progressbar" style="display:none"></div>
# </div>
# <div class="gallery manga-gallery">
# <h1><a href="/reader/1262452.html">Minatsu no Sei | 미나츠의 탓</a></h1>
# <h2>
# <ul class="comma-list">
# <li><a href="/artist/henreader-all-1.html">henreader</a></li>
# </ul>
# </h2>
# <div class="gallery-info">
# <table>
# <tr>
# <td>Group</td><td>
#                     N/A
#                     </td>
# </tr>
# <tr>
# <td>Type</td><td>
# <a href="/type/manga-all-1.html">
#
#                         manga
#
#
#
#                         </a></td>
# </tr>
# <tr>
# <td>Language</td><td><a href="/index-korean-1.html">한국어</a></td>
# </tr>
# <tr>
# <td>Series</td><td>
#                     N/A
#                     </td>
# </tr>
# <tr>
# <td>Characters</td><td>
# <ul class="tags">
# </ul>
# </td>
# </tr>
# <tr>
# <td>Tags</td><td><ul class="tags">
# <li><a href="/tag/female%3Aloli-all-1.html">loli ♀</a></li>
# <li><a href="/tag/female%3Asister-all-1.html">sister ♀</a></li>
# <li><a href="/tag/female%3Asole%20female-all-1.html">sole female ♀</a></li>
# <li><a href="/tag/incest-all-1.html">incest</a></li>
# <li><a href="/tag/male%3Aglasses-all-1.html">glasses ♂</a></li>
# <li><a href="/tag/male%3Asole%20male-all-1.html">sole male ♂</a></li>
# <li><a href="/tag/mosaic%20censorship-all-1.html">mosaic censorship</a></li>
# </ul>
# </td>
# </tr>
# </table>
# <span class="date">2018-07-28 11:57:00-05</span>
# </div>
# </div>
# <div class="gallery-preview lillie">
# <script>
# var scene_indexes = [];
# </script>
# <ul class="thumbnail-list"></ul>
# </div>
# </div>
# <div class="top-content"><div class="list-title"><h3>Related Galleries</h3></div></div>
# <div class="gallery-content"></div>
# <div class="donate">Donate BTC: 14ko11NvcemFm2q5NpjpGiTbPhmB8pfnpC</div>
# </div>
# </body>
# </html>
